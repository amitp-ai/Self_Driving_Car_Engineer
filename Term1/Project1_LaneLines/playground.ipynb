# %%
ls
# Out:
# challenge.mp4              P1.ipynb               solidYellowLeft.mp4
# laneLines_thirdPass.jpg    raw-lines-example.mp4  test_images/
# line-segments-example.jpg  README.md              Untitled.ipynb
# P1_example.mp4             solidWhiteRight.mp4

# %%
pwd
# Out:
# '/home/amit/Desktop/AmitProjects/SDCND/Readings/image_processing'

# %%
ls
# Out:
# brooklyn_bridge.png  fruits.png  Image_processing_tutorial.ipynb

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# lets look at an example image.
fruits = mpimg.imread('fruits.png')
plt.imshow(fruits)

# %%
for i,c in zip(range(3),['Reds','Greens','Blues']):
    plt.imshow(fruits[:,:,i], cmap=c)
    plt.show()
